# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Hoteldata.csv')
df.head(10)
# Out:
#                                            Names Prices Neighbourhoods  \
# 0                                     The Circus     €€          Mitte
# 1                                     Soho House    €€€     Prenzlauer
# 2   Hotel Axel Springer am Deutschen Herzzentrum    €€€        Wedding
# 3                               elite city guide    NaN            NaN
# 4                                    Steps-Hotel    NaN            NaN
# 5                                 Schall & Rauch     €€     Prenzlauer
# 6                                      i31 Hotel     €€          Mitte
# 7                                       The Dude     €€          Mitte
# 8                       Mercure Hotel MOA Berlin     €€     Tiergarten
# 9  AC Hotel by Marriott Berlin Humboldthain Park    NaN            NaN
#
#    Number_of_reviews  Ratings        Type_of_hotels
# 0               33.0      4.5                Hotels
# 1               85.0      4.0                Hotels
# ...

# %%
# df.info()

# %%
df['Neighbourhoods'].value_counts().plot(kind = 'bar' )
plt.xlabel('Locations')
plt.ylabel('Counts')
plt.title('Location with most hotels')
# Out:
# Text(0.5, 1.0, 'Location with most hotels')

# %%
df2 = df[['Type_of_hotels','Number_of_reviews']]
trying = df2.groupby('Type_of_hotels',as_index=False).sum()
trying.sort_values('Number_of_reviews',ascending=False)
# df2.groupby('Type_of_hotels').sum()
# Out:
#            Type_of_hotels  Number_of_reviews
# 14                 Hotels             2554.0
# 42           HotelsVenues              213.0
# 6               BarsClubs               47.0
# 47               Pensions               38.0
# 10  HostelsFriedrichshain               29.0
# 12      HostelsPrenzlauer               26.0
# 11          HostelsHotels               22.0
# 22           HotelsHealth               19.0
# 20           HotelsGerman               17.0
# 9      GermanPensionsBeer               16.0
# 1              B&BsHotels               14.0
# 25        HotelsKreuzberg               11.0
# 21            HotelsGuest                9.0
# 29            HotelsMitte                8.0
# 15             HotelsB&Bs                5.0
# 43          HotelsWedding                4.0
# 4          B&BsPrenzlauer                4.0
# 5          BarsB&BsHotels                3.0
# 38         HotelsSteglitz                3.0
# 31           HotelsPankow                3.0
# ...
